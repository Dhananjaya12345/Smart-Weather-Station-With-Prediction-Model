# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np

# Importing the dataset
weather_dataset = pd.read_csv('5 day forcast2.csv')
print(weather_dataset)

# Shuffling the data
np.random.shuffle(weather_dataset.values)
print(weather_dataset.values)

# Conversion of the date field into integer format
day_dic = {
    'San': 1,
    'Man': 2,
    'Tues': 3,
    'Wedn': 4,
    'Thur': 5
}
print(day_dic)
print(weather_dataset['Day'])

# Formulating inputs
weather_inputs = np.column_stack((weather_dataset.Day.map(day_dic).values, weather_dataset.Time.values, weather_dataset.Temperature.values, weather_dataset.Humidity.values, weather_dataset.UV_level.values))
print(weather_inputs)

# Formulating outputs
weather_outputs = np.column_stack((weather_dataset.Rain.values, weather_dataset.Wind_Speed.values))
print(weather_outputs)

print()
print('Building the neural network')

# Preparing the neural network
weather_NN = keras.Sequential([
    keras.layers.Dense(128, input_shape=(5,), activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(8, activation='relu'),
    keras.layers.Dense(2)  # Output layer with linear activation
])

# Compiling the neural network
weather_NN.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# Fitting the model
weather_NN.fit(weather_inputs.astype(np.float32), weather_outputs.astype(np.float32), batch_size=4, epochs=200)

# Predicting the rain and wind speed
prediction = weather_NN.predict(np.column_stack((np.array([3]), np.array([11000]), np.array([28]), np.array([84.2]), np.array([12300]))))

# Apply threshold for rain prediction
rain_threshold = 0.5
binary_rain_prediction = 1 if prediction[0][0] >= rain_threshold else 0

print('Prediction - Rain (Binary):', binary_rain_prediction)  # 0 or 1
print('Prediction - Wind Speed:', prediction[0][1])  # Predicted wind speed
# Out:
#         Day   Time  entry_id  Temperature  Humidity  UV_level  Rain  \
# 0       San  60000         1         31.2      87.1        22     1
# 1       San  60020         2         31.2      87.3        23     1
# 2       San  60040         3         31.2      87.3        32     1
# 3       San  60100         4         31.2      87.2       322     1
# 4       San  60120         5         31.2      87.0        33     1
# ...     ...    ...       ...          ...       ...       ...   ...
# 21596  Thur  55820     21597         30.8      86.5         0     0
# 21597  Thur  55840     21598         30.8      86.5         0     0
# 21598  Thur  55900     21599         30.8      86.5         0     0
# 21599  Thur  55920     21600         30.8      86.6         0     0
# 21600  Thur  55940     21601         30.9      87.0         0     0
#
#        Wind_Speed
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4            2.85
# ...           ...
# 21596        4.23
# 21597        5.13
# 21598        4.43
# 21599        4.87
# 21600        3.67
#
# [21601 rows x 8 columns]
# [['San' 60000 1 ... 22 1 0.0]
#  ['San' 60020 2 ... 23 1 0.0]
#  ['San' 60040 3 ... 32 1 0.0]
#  ...
#  ['Thur' 55900 21599 ... 0 0 4.43]
#  ['Thur' 55920 21600 ... 0 0 4.87]
#  ['Thur' 55940 21601 ... 0 0 3.67]]
# {'San': 1, 'Man': 2, 'Tues': 3, 'Wedn': 4, 'Thur': 5}
# 0         San
# 1         San
# 2         San
# 3         San
# 4         San
#          ...
# 21596    Thur
# 21597    Thur
# 21598    Thur
# 21599    Thur
# 21600    Thur
# Name: Day, Length: 21601, dtype: object
# [[1.000e+00 6.000e+04 3.120e+01 8.710e+01 2.200e+01]
#  [1.000e+00 6.002e+04 3.120e+01 8.730e+01 2.300e+01]
#  [1.000e+00 6.004e+04 3.120e+01 8.730e+01 3.200e+01]
#  ...
#  [5.000e+00 5.590e+04 3.080e+01 8.650e+01 0.000e+00]
#  [5.000e+00 5.592e+04 3.080e+01 8.660e+01 0.000e+00]
#  [5.000e+00 5.594e+04 3.090e+01 8.700e+01 0.000e+00]]
# [[1.   0.  ]
#  [1.   0.  ]
#  [1.   0.  ]
#  ...
#  [0.   4.43]
#  [0.   4.87]
#  [0.   3.67]]
#
# Building the neural network
# Epoch 1/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 5210.6675 - accuracy: 0.8596
# Epoch 2/200
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7349 - accuracy: 0.8772
# Epoch 3/200
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7420 - accuracy: 0.8772
# Epoch 4/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7376 - accuracy: 0.8772
# Epoch 5/200
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7404 - accuracy: 0.8772
# Epoch 6/200
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7327 - accuracy: 0.8772
# Epoch 7/200
# 5401/5401 [==============================] - 35s 6ms/step - loss: 10.7302 - accuracy: 0.8772
# Epoch 8/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7238 - accuracy: 0.8772
# Epoch 9/200
# 5401/5401 [==============================] - 34s 6ms/step - loss: 10.7239 - accuracy: 0.8772
# Epoch 10/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7281 - accuracy: 0.8772
# Epoch 11/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7239 - accuracy: 0.8772
# Epoch 12/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7262 - accuracy: 0.8772
# Epoch 13/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7211 - accuracy: 0.8772
# Epoch 14/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7215 - accuracy: 0.8772
# Epoch 15/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7249 - accuracy: 0.8772
# Epoch 16/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7238 - accuracy: 0.8772
# Epoch 17/200
# 5401/5401 [==============================] - 34s 6ms/step - loss: 10.7130 - accuracy: 0.8772
# Epoch 18/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7186 - accuracy: 0.8772
# Epoch 19/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7216 - accuracy: 0.8772
# Epoch 20/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7175 - accuracy: 0.8772
# Epoch 21/200
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7242 - accuracy: 0.8772
# Epoch 22/200
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7167 - accuracy: 0.8772
# Epoch 23/200
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7196 - accuracy: 0.8772
# Epoch 24/200
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7189 - accuracy: 0.8772
# Epoch 25/200
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7210 - accuracy: 0.8772
# Epoch 26/200
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7187 - accuracy: 0.8772
# Epoch 27/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7178 - accuracy: 0.8772
# Epoch 28/200
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7153 - accuracy: 0.8772
# Epoch 29/200
# 5401/5401 [==============================] - 39s 7ms/step - loss: 10.7172 - accuracy: 0.8772
# Epoch 30/200
# 5401/5401 [==============================] - 48s 9ms/step - loss: 10.7204 - accuracy: 0.8772
# Epoch 31/200
# 5401/5401 [==============================] - 38s 7ms/step - loss: 10.7194 - accuracy: 0.8772
# Epoch 32/200
# 5401/5401 [==============================] - 39s 7ms/step - loss: 10.7173 - accuracy: 0.8772
# Epoch 33/200
# 5401/5401 [==============================] - 38s 7ms/step - loss: 10.7117 - accuracy: 0.8772
# Epoch 34/200
# 5401/5401 [==============================] - 37s 7ms/step - loss: 10.