# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np

# Importing the dataset
weather_dataset = pd.read_csv('5 day forcast.csv')
print(weather_dataset)

# Shuffling the data
np.random.shuffle(weather_dataset.values)
print(weather_dataset.values)

# Conversion of the date field into integer format
day_dic = {
    'San': 1,
    'Man': 2,
    'Tues': 3,
    'Wedn': 4,
    'Thur': 5
}
print(day_dic)
print(weather_dataset['Day'])

# Formulating inputs
weather_inputs = np.column_stack((weather_dataset.Day.map(day_dic).values, weather_dataset.Time.values, weather_dataset.Temperature.values, weather_dataset.Humidity.values, weather_dataset.UV_level.values))
print(weather_inputs)

# Formulating outputs
weather_outputs = np.column_stack((weather_dataset.Rain.values, weather_dataset.Wind_Speed.values))
print(weather_outputs)

print()
print('Building the neural network')

# Preparing the neural network
weather_NN = keras.Sequential([
    keras.layers.Dense(128, input_shape=(5,), activation='relu'),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(8, activation='relu'),
    keras.layers.Dense(2)  # Output layer with linear activation
])

# Compiling the neural network
weather_NN.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# Fitting the model
weather_NN.fit(weather_inputs.astype(np.float32), weather_outputs.astype(np.float32), batch_size=4, epochs=100)

# Predicting the rain and wind speed
prediction = weather_NN.predict(np.column_stack((np.array([4]), np.array([220020]), np.array([30.7]), np.array([93.7]), np.array([0]))))

print('Prediction - Rain:', prediction[0][0])  # Index 0 corresponds to the prediction of rain
print('Prediction - Wind Speed:', prediction[0][1])  # Index 1 corresponds to the prediction of wind speed
# Out:
#         Day   Time  entry_id  Temperature  Humidity  UV_level  Rain  \
# 0       San  60000         1         31.2      87.1        22     1
# 1       San  60020         2         31.2      87.3        23     1
# 2       San  60040         3         31.2      87.3        32     1
# 3       San  60100         4         31.2      87.2       322     1
# 4       San  60120         5         31.2      87.0        33     1
# ...     ...    ...       ...          ...       ...       ...   ...
# 21596  Thur  55820     21597         30.8      86.5         0     0
# 21597  Thur  55840     21598         30.8      86.5         0     0
# 21598  Thur  55900     21599         30.8      86.5         0     0
# 21599  Thur  55920     21600         30.8      86.6         0     0
# 21600  Thur  55940     21601         30.9      87.0         0     0
#
#        Wind_Speed
# 0            0.00
# 1            0.00
# 2            0.00
# 3            0.00
# 4            2.85
# ...           ...
# 21596        4.23
# 21597        5.13
# 21598        4.43
# 21599        4.87
# 21600        3.67
#
# [21601 rows x 8 columns]
# [['San' 60000 1 ... 22 1 0.0]
#  ['San' 60020 2 ... 23 1 0.0]
#  ['San' 60040 3 ... 32 1 0.0]
#  ...
#  ['Thur' 55900 21599 ... 0 0 4.43]
#  ['Thur' 55920 21600 ... 0 0 4.87]
#  ['Thur' 55940 21601 ... 0 0 3.67]]
# {'San': 1, 'Man': 2, 'Tues': 3, 'Wedn': 4, 'Thur': 5}
# 0         San
# 1         San
# 2         San
# 3         San
# 4         San
#          ...
# 21596    Thur
# 21597    Thur
# 21598    Thur
# 21599    Thur
# 21600    Thur
# Name: Day, Length: 21601, dtype: object
# [[1.000e+00 6.000e+04 3.120e+01 8.710e+01 2.200e+01]
#  [1.000e+00 6.002e+04 3.120e+01 8.730e+01 2.300e+01]
#  [1.000e+00 6.004e+04 3.120e+01 8.730e+01 3.200e+01]
#  ...
#  [5.000e+00 5.590e+04 3.080e+01 8.650e+01 0.000e+00]
#  [5.000e+00 5.592e+04 3.080e+01 8.660e+01 0.000e+00]
#  [5.000e+00 5.594e+04 3.090e+01 8.700e+01 0.000e+00]]
# [[1.   0.  ]
#  [1.   0.  ]
#  [1.   0.  ]
#  ...
#  [0.   4.43]
#  [0.   4.87]
#  [0.   3.67]]
#
# Building the neural network
# Epoch 1/100
# 5401/5401 [==============================] - 38s 6ms/step - loss: 9806.8594 - accuracy: 0.8552
# Epoch 2/100
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7092 - accuracy: 0.8772
# Epoch 60/100
# 5401/5401 [==============================] - 46s 9ms/step - loss: 10.7071 - accuracy: 0.8772
# Epoch 61/100
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7084 - accuracy: 0.8772
# Epoch 64/100
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7058 - accuracy: 0.8772
# Epoch 65/100
# 5401/5401 [==============================] - 30s 5ms/step - loss: 10.7076 - accuracy: 0.8772
# Epoch 66/100
# 5401/5401 [==============================] - 30s 6ms/step - loss: 10.7069 - accuracy: 0.8772
# Epoch 67/100
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7080 - accuracy: 0.8772
# Epoch 68/100
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7057 - accuracy: 0.8772
# Epoch 69/100
# 5401/5401 [==============================] - 28s 5ms/step - loss: 10.7066 - accuracy: 0.8772
# Epoch 70/100
# 5401/5401 [==============================] - 29s 5ms/step - loss: 10.7092 - accuracy: 0.8772
# Epoch 71/100
# 5401/5401 [==============================] - 41s 8ms/step - loss: 10.7090 - accuracy: 0.8772
# Epoch 72/100
# 5401/5401 [==============================] - 40s 7ms/step - loss: 10.7080 - accuracy: 0.8772
# Epoch 73/100
# 5401/5401 [==============================] - 34s 6ms/step - loss: 10.7059 - accuracy: 0.8772
# Epoch 74/100
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7058 - accuracy: 0.8772
# Epoch 75/100
# 5401/5401 [==============================] - 44s 8ms/step - loss: 10.7083 - accuracy: 0.8772
# Epoch 76/100
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7075 - accuracy: 0.8772
# Epoch 77/100
# 5401/5401 [==============================] - 33s 6ms/step - loss: 10.7032 - accuracy: 0.8772
# Epoch 78/100
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7092 - accuracy: 0.8772
# Epoch 79/100
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7090 - accuracy: 0.8772
# Epoch 80/100
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7092 - accuracy: 0.8772
# Epoch 81/100
# 5401/5401 [==============================] - 32s 6ms/step - loss: 10.7071 - accuracy: 0.8772
# Epoch 82/100
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7087 - accuracy: 0.8772
# Epoch 83/100
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7057 - accuracy: 0.8772
# Epoch 84/100
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7064 - accuracy: 0.8772
# Epoch 85/100
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7036 - accuracy: 0.8772
# Epoch 86/100
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7046 - accuracy: 0.8772
# Epoch 87/100
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7085 - accuracy: 0.8772
# Epoch 88/100
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7065 - accuracy: 0.8772
# Epoch 89/100
# 5401/5401 [==============================] - 34s 6ms/step - loss: 10.7049 - accuracy: 0.8772
# Epoch 90/100
# 5401/5401 [==============================] - 35s 6ms/step - loss: 10.7091 - accuracy: 0.8772
# Epoch 91/100
# 5401/5401 [==============================] - 37s 7ms/step - loss: 10.7081 - accuracy: 0.8772
# Epoch 92/100
# 5401/5401 [==============================] - 37s 7ms/step - loss: 10.7047 - accuracy: 0.8772
# Epoch 93/100
# 5401/5401 [==============================] - 37s 7ms/step - loss: 10.7040 - accuracy: 0.8772
# Epoch 94/100
# 5401/5401 [==============================] - 36s 7ms/step - loss: 10.7069 - accuracy: 0.8772
# Epoch 95/100
# 5401/5401 [==============================] - 37s 7ms/step - loss: 10.7071 - accuracy: 0.8772
# Epoch 96/100
# 5401/5401 [==============================] - 34s 6ms/step - loss: 10.7059 - accuracy: 0.8772
# Epoch 97/100
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7071 - accuracy: 0.8772
# Epoch 98/100
# 5401/5401 [==============================] - 31s 6ms/step - loss: 10.7098 - accuracy: 0.8772
# Epoch 99/100
# 5401/5401 [==============================] - 30s 6ms/step - loss: 10.7068 - accuracy: 0.8772
# Epoch 100/100
# 5401/5401 [==============================] - 29s 5ms/step - loss: 10.7026 - accuracy: 0.8772
# 1/1 [==============================] - 1s 633ms/step
# Prediction - Rain: 0.19835092
# Prediction - Wind Speed: 3.4654517

# %%
# Calculate the accuracy
loss, accuracy = weather_NN.evaluate(weather_inputs.astype(np.float32), weather_outputs.astype(np.float32))
print('Accuracy:', accuracy)
# Out:
# 676/676 [==============================] - 5s 5ms/step - loss: 10.6999 - accuracy: 0.8772
# Accuracy: 0.8771815896034241
